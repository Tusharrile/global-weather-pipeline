# %%
# Test that Databricks can see your S3 bucket via Unity Catalog External Location

files = dbutils.fs.ls("s3://global-weather-pipeline/")
for f in files:
    print(f"{f.name}")

# %%
# %sql
SELECT * FROM global_weather_catalog.bronze.src_weather LIMIT 10;

# %%
# %sql
SELECT * FROM global_weather_catalog.silver.weather_silver LIMIT 10
